# %% [markdown]
# <a href="https://colab.research.google.com/github/tzellas/predictive_process_mining_ml/blob/master/event_log_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Predictive Process Mining Diploma Theses
#
# **Description**
#
#
# ---
# ICL Prompting on LLMs with RAG for Predictive Process Monitoring.

# %% [markdown]
# ## Event Log Preprocessing
#
#
# ---
# Here we will parse the XES event log, extract prefixes and store them as embeddings in a vector index.

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# !pip install pm4py
import pm4py
import csv


trace_identifier = "case:concept:name"

event_logs = {
                  "2019" : "BPI_Challenge_2019.xes",
                  "2020" : "BPI_Challenge_2020.xes"
                }

xes_data_path = "/content/drive/MyDrive/Predictive Process Monitoring /data/XES FILES/"

csv_relults_path = "/content/drive/MyDrive/Predictive Process Monitoring /data/CSV RESULTS/"

def read_clean_log(event_log_id):

  xes_log  = pm4py.read_xes(xes_data_path + event_logs[event_log_id])
  df_log = pm4py.convert_to_dataframe(xes_log)

  # sort traces by trace id and timestamp
  df_log = df_log.sort_values([trace_identifier, "time:timestamp"]).reset_index(drop=True)

  # ignore trace attributes except trace id
  keep_cols = [
      c for c in df_log.columns if not c.startswith("case:") or c == trace_identifier
  ]

  df_log = df_log[keep_cols].copy()
  return df_log



def build_prefixes(df_log: pd.DataFrame, base: int = 1, gap: int = 3):
  seen_prefixes = set()
  prefixes = []
  j_map = {}
  j = 1

  # iterate through events of a single trace
  for trace_id ,df_trace in df_log.groupby(trace_identifier, sort=False):

    if len(df_trace) <= 2:
      continue

    df_trace = df_trace.reset_index(drop=True)

    cl_list = ""
    values = {}
    # keep only indexes that match the selected bucketing
    for i in range(base, len(df_trace)-1, gap):
      if i == base:
        start = 0
      else:
        start = i-gap+1
      # process events from last to next gap
      for event_index in range(start,i+1):

        event = df_trace.iloc[event_index]
        if event_index == 0:
          cl_list = f"{event['concept:name']}"
        else:
          cl_list += f",{event["concept:name"]}"

        for key, value in event.items():
          if key in {"concept:name", trace_identifier}:
            continue
          if key not in j_map:
            j_map[key] = ''.join([part[:2] for part in key.split(':')])
            j += 1
          values[j_map[key]] = str(value)
      if cl_list in seen_prefixes:
        continue
      seen_prefixes.add(cl_list)

      final_prefix_string = f"{cl_list} - Values: {values} - {df_trace.iloc[i+1]["concept:name"]}"
      prefixes.append(final_prefix_string)
  return prefixes


pref_list_2020 = build_prefixes(read_clean_log("2020"))
print(pref_list_2020)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: pm4py in /usr/local/lib/python3.12/dist-packages (2.7.19.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pm4py) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pm4py) (2.2.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from pm4py) (3.6.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from pm4py) (0.21)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pm4py) (1.16.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from pm4py) (6.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pm4py) (3.10.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from pm4py) (2025.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pm4py) (4.67.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (from pm4py) (0.45.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pm4py) (75.2.0)
# Requirement already satisfied: cvxopt in /usr/local/lib/python3.12/dist-packages (from pm4py) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pm4py) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pm4py) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pm4py) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pm4py) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pm4py) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pm4py) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pm4py) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pm4py) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pm4py) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->pm4py) (1.17.0)
# parsing log, completed traces ::   0%|          | 0/6449 [00:00<?, ?it/s]
# ["Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION - Values: {'id': 'st_step 1005_0', 'orre': 'STAFF MEMBER', 'titi': '2018-03-01 10:55:21+00:00', 'orro': 'ADMINISTRATION'} - Permit FINAL_APPROVED by SUPERVISOR", "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit FINAL_APPROVED by SUPERVISOR,Start trip,End trip - Values: {'id': 'rv_travel permit 992_7', 'orre': 'STAFF MEMBER', 'titi': '2018-03-23 00:00:00+00:00', 'orro': 'EMPLOYEE'} - Declaration SUBMITTED by EMPLOYEE", "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit FINAL_APPROVED by SUPERVISOR,Start trip,End trip,Declaration SUBMITTED by EMPLOYEE,Declaration APPROVED by ADMINISTRATION,Declaration FINAL_APPROVED by SUPERVISOR - Values: {'id': 'st_step 1017_0', 'orre': 'STAFF MEMBER', 'titi': '2018-04-05 09:45:53+00:00', 'orro': 'SUPERVISOR'} - Request Payment", "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit APPROVED by BUDGET OWNER,Permit FINAL_APPROVED by SUPERVISOR,Start trip - Values: {'id': 'rv_travel permit 10022_6', 'orre': 'STAFF MEMBER', 'titi': '2018-03-17 00:00:00+00:00', 'orro': 'EMPLOYEE'} - End trip", "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit APPROVED by BUDGET OWNER,Permit FINAL_APPROVED by SUPERVISOR,Start trip,End trip,Declaration SUBMITTED by EMPLOYEE,Declaration APPROVED by ADMINISTRATION - Values: {'id': 'st_step 10035_0', 'orre': 'STAFF MEMBER', 'titi': '2018-04-16 21:14:17+00:00', 'orro': 'ADMINISTRATION'} - Declaration APPROVED by BUDGET OWNER", "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit APPROVED by BUDGET OWNER,Permit FINAL_APPROVED by SUPERVISOR,Start trip,End trip,Declaration SUBMITTED by EMPLOYEE,Declaration APPROVED by ADMINISTRATION,Declaration APPROVED by BUDGET OWNER,Declaration FINAL_APPROVED by SUPERVISOR,Request Payment - Values: {'id': 'fd_declaration 10024_17', 'orre': 'SYSTEM', 'titi': '2018-04-19 09:15:49+00:00', 'orro': 'UNDEFINED'} - Payment Handled", "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Start trip,End trip,Permit FINAL_APPROVED by SUPERVISOR - Values: {'id': 'st_step 10073_0', 'orre': 'STAFF MEMBER', 'titi': '2018-02-22 08:27:05+00:00', 'orro': 'SUPERVISOR'} - Declaration SUBMITTED by EMPLOYEE", "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Start trip,End trip,Permit FINAL_APPROVED by SUPERVISOR,Declaration SUBMITTED by EMPLOYEE,Declaration APPROVED by ADMINISTRATION,Declaration FINAL_APPROVED by SUPERVISOR - Values: {'id': 'st_step 10075_0', 'orre': 'STAFF MEMBER', 'titi': '2018-02-26 10:01:52+00:00', 'orro': 'SUPERVISOR'} - Request Payment", "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit FINAL_APPROVED by SUPERVISOR,Start trip,Declaration SUBMITTED by EMPLOYEE - Values: {'id': 'st_step 10097_0', 'orre': 'STAFF MEMBER', 'titi': '2018-04-27 21:12:34+00:00', 'orro': 'EMPLOYEE'} - End trip", "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit FINAL_APPROVED by SUPERVISOR,Start trip,Declaration SUBMITTED by EMPLOYEE,End trip,Declaration REJECTED by ADMINISTRATION,Declaration REJECTED by EMPLOYEE - Values: {'id': 'st_step 10098_0', 'orre': 'STAFF MEMBER', 'titi': '2018-05-03 10:34:34+00:00', 'orro': 'EMPLOYEE'} - Declaration SUBMITTED by EMPLOYEE", "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit FINAL_APPROVED by SUPERVISOR,Start trip,Declaration SUBMITTED by EMPLOYEE,End trip,Declaration REJECTED by ADMINISTRATION,Declaration REJECTED by EMPLOYEE,Declaration SUBMITTED by EMPLOYEE,Declaration APPROVED by ADMINISTRATION,Declaration FINAL_APPROVED by SUPERVISOR - Values: {'id': 'st_step 10096_0', 'orre': 'STAFF MEMBER', 'titi': '2018-05-15 13:42:10+00:00', 'orro': 'SUPERVISOR'} - Request Payment", "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit APPROVED by BUDGET OWNER,Permit FINAL_APPROVED by SUPERVISOR,Start trip,End trip,Send Reminder,Declaration SUBMITTED by EMPLOYEE - Va ...

# %%
def convert_to_csv(prefix_list, event_log_id):
  rows = []
  for row in prefix_list:
    rows.append((f"{' - '.join(row.split(' - ', 2)[:2]).strip()}",f"{row.split(' - ',2)[2].strip()}" ))

  path = f"{csv_relults_path}{event_logs[event_log_id].removesuffix("xes")}csv"

  with open(path, "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["prefix", "prediction"])
        w.writerows(rows)

convert_to_csv(pref_list_2020, "2020")


def reduced_csv(event_log_id, max_rows: int = 300):
    path = f"{csv_relults_path}{event_logs[event_log_id].removesuffix("xes")}csv"
    reduced_path = f"{csv_relults_path}reduced_{event_logs[event_log_id].removesuffix("xes")}csv"
    with open(path, "r", encoding="utf-8", newline="") as f:
      reader = csv.reader(f)
      header = next(reader)
      rows = []
      for i, row in enumerate(reader):
          if i >= max_rows:
              break
          rows.append(row)

    with open(reduced_path, "w", encoding="utf-8", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(header)
        writer.writerows(rows)

reduced_csv("2020")

# %%
def search_csv_column(
    event_log_id,
    column_name: str,
    search_string: str
):
    matches = []
    path = f"{csv_relults_path}{event_logs[event_log_id].removesuffix('xes')}csv"

    with open(path, newline="", encoding="utf-8") as f:
        reader = csv.DictReader(f)

        if column_name not in reader.fieldnames:
            raise ValueError(f"Column '{column_name}' not found")

        for row in reader:
            if search_string in row[column_name]:
                matches.append(row)

    return matches

# %%
search_csv_column("2020", "prefix", "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit REJECTED by SUPERVISOR,Permit REJECTED by EMPLOYEE,Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit APPROVED by BUDGET OWNER,Start trip,Permit FINAL_APPROVED by SUPERVISOR,End trip,Declaration SUBMITTED by EMPLOYEE,Declaration REJECTED by ADMINISTRATION,Declaration REJECTED by EMPLOYEE,Declaration SUBMITTED by EMPLOYEE - Values: {'id': 'st_step 27246_0', 'orre': 'STAFF MEMBER', 'titi': '2018-11-28")
# Out:
# [{'prefix': "Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit REJECTED by SUPERVISOR,Permit REJECTED by EMPLOYEE,Permit SUBMITTED by EMPLOYEE,Permit APPROVED by ADMINISTRATION,Permit APPROVED by BUDGET OWNER,Start trip,Permit FINAL_APPROVED by SUPERVISOR,End trip,Declaration SUBMITTED by EMPLOYEE,Declaration REJECTED by ADMINISTRATION,Declaration REJECTED by EMPLOYEE,Declaration SUBMITTED by EMPLOYEE - Values: {'id': 'st_step 27246_0', 'orre': 'STAFF MEMBER', 'titi': '2018-11-28 15:49:59+00:00', 'orro': 'EMPLOYEE'}",
#   'prediction': 'Declaration APPROVED by ADMINISTRATION'}]
